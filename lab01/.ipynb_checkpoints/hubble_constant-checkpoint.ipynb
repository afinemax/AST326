# %% [markdown]
# # AST326 lab01
# ### Maxwell Fine 1004714400
#
# Ex 06: Calculation of the Hubble constant using the straight-line linear least squares fitting.
# The file has two columns: the
# first column is a list of the distances (in unit of mega-parsec [Mpc]) of 13 galaxies in the range
# of 12000 Mpc; the second column gives the observed receding velocities of the galaxies in
# unit of km s  1 . Using the data in the file, calculate the Hubble constant with its uncertainty by
# applying the linear least squares fitting method. You need to use your own codes for this
# assignment; in other words, you are NOT allowed to use a built-in Python library for the
# fitting.

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np

# data fnames
hubble_f = 'data/Fine-finemaxw-Hubble.txt'

# %%
# load data
hubble_data = np.genfromtxt(fname=hubble_f)
distance = hubble_data[:,0] # in Mpc
rec_vel = hubble_data[:,1] # in kms^-1

# %%
plt.plot(rec_vel, distance, label="Raw Data")
plt.legend(fontsize=12)
plt.xlabel('Recession Velocity', fontize=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 plt.plot(rec_vel, distance, label="Raw Data")
#       2 plt.legend(fontsize=12)
# ----> 3 plt.xlabel('Recession Velocity', fontize=15)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:3033, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3031 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    3032 def xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# -> 3033     return gca().set_xlabel(
#    3034         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
#    3035         **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:3504, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3501     elif loc == 'right':
#    3502         kwargs.update(x=1, horizontalalignment='right')
# -> 3504 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1563, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1561 if fontdict is not None:
#    1562     self.label.update(fontdict)
# -> 1563 self.label.update(kwargs)
#    1564 self.stale = True
#    1565 return self.label
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py:172, in Text.update(self, kwargs)
#     170 # Update bbox last, as it depends on font properties.
#     171 bbox = kwargs.pop("bbox", sentinel)
# --> 172 super().update(kwargs)
#     173 if bbox is not sentinel:
#     174     self.set_bbox(bbox)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Text' object has no property 'fontize'
